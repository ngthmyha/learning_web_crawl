# %%
from scrapy.crawler import CrawlerProcess
from scrapy import Spider
from scrapy.utils.project import get_project_settings

# Định nghĩa Spider
class BlogSpider(Spider):
    name = 'blog_spider'
    start_urls = ['https://newbreak.church/blog/?gad_source=1&gclid=Cj0KCQiA7NO7BhDsARIsADg_hIb6THWfJcUdxD9HMXljPV1Vyxk0JRYy_zhQUtnw8Hmr-s6GB19FuZAaAmuIEALw_wcB']
    custom_settings = {
        'DEFAULT_REQUEST_HEADERS': {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.82 Safari/537.36'
        }
    }

    def parse(self, response):
        # Lấy danh sách các bài viết
        blogs = response.css('div.fl-post-column')
        print(blogs)
        for blog in blogs:
            yield {
                'title': blog.css('h2.fl-post-grid-title a::text').get(),
                'link': blog.css('h2.fl-post-grid-title a::attr(href)').get(),
                'date': blog.css('span.fl-post-grid-date::text').get(),
                'image': blog.css('img::attr(src)').get(),
            }
        
        # Xử lý pagination (trang kế tiếp)
        next_page = response.css('a.next-page::attr(href)').get()
        if next_page:
            yield response.follow(next_page, self.parse)

# Tạo hàm chạy Scrapy trong Notebook
def run_spider(spider):
    # os._exit(00)
    process = CrawlerProcess(get_project_settings())
    process.crawl(spider)
    process.start()

# Chạy spider
run_spider(BlogSpider)
# Out:
# 2025-01-02 09:33:43 [scrapy.utils.log] INFO: Scrapy 2.11.2 started (bot: scrapybot)
# 2025-01-02 09:33:43 [scrapy.utils.log] INFO: Versions: lxml 5.3.0.0, libxml2 2.12.9, cssselect 1.2.0, parsel 1.9.1, w3lib 2.2.1, Twisted 24.7.0, Python 3.13.0 (v3.13.0:60403a5409f, Oct  7 2024, 00:37:40) [Clang 15.0.0 (clang-1500.3.9.4)], pyOpenSSL 24.2.1 (OpenSSL 3.3.2 3 Sep 2024), cryptography 43.0.3, Platform macOS-14.2-arm64-arm-64bit-Mach-O
# 2025-01-02 09:33:43 [scrapy.addons] INFO: Enabled addons:
# []
# 2025-01-02 09:33:43 [py.warnings] WARNING: /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scrapy/utils/request.py:254: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2025-01-02 09:33:43 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2025-01-02 09:33:43 [scrapy.extensions.telnet] INFO: Telnet Password: 0f07d86e497135fd
# 2025-01-02 09:33:43 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2025-01-02 09:33:43 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2025-01-02 09:33:43 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2025-01-02 09:33:43 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2025-01-02 09:33:43 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2025-01-02 09:33:43 [scrapy.core.engine] INFO: Spider opened
# 2025-01-02 09:33:43 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2025-01-02 09:33:43 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6024
# 2025-01-02 09:33:43 [scrapy.core.engine] DEBUG: Crawled (520) <GET https://newbreak.church/blog/?gad_source=1&gclid=Cj0KCQiA7NO7BhDsARIsADg_hIb6THWfJcUdxD9HMXljPV1Vyxk0JRYy_zhQUtnw8Hmr-s6GB19FuZAaAmuIEALw_wcB> (referer: None)
# 2025-01-02 09:33:44 [scrapy.spidermiddlewares.httperror] INFO: Ignoring response <520 https://newbreak.church/blog/?gad_source=1&gclid=Cj0KCQiA7NO7BhDsARIsADg_hIb6THWfJcUdxD9HMXljPV1Vyxk0JRYy_zhQUtnw8Hmr-s6GB19FuZAaAmuIEALw_wcB>: HTTP status code is not handled or not allowed
# 2025-01-02 09:33:44 [scrapy.core.engine] INFO: Closing spider (finished)
# 2025-01-02 09:33:44 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 318,
#  'downloader/request_count': 1,
#  'downloader/request_method_count/GET': 1,
#  'downloader/response_bytes': 431,
#  'downloader/response_count': 1,
#  'downloader/response_status_count/520': 1,
#  'elapsed_time_seconds': 0.577903,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2025, 1, 2, 2, 33, 44, 63366, tzinfo=datetime.timezone.utc),
#  'httperror/response_ignored_count': 1,
#  'httperror/response_ignored_status_count/520': 1,
#  'log_count/DEBUG': 2,
#  'log_count/INFO': 11,
#  'log_count/WARNING': 1,
#  'memusage/max': 110346240,
#  'memusage/startup': 110346240,
#  'response_received_count': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2025, 1, 2, 2, 33, 43, 485463, tzinfo=datetime.timezone.utc)}
# 2025-01-02 09:33:44 [scrapy.core.engine] INFO: Spider closed (finished)

# %%
import requests
from bs4 import BeautifulSoup

# Hàm xử lý một trang blog
def scrape_blog_page(url):
    response = requests.get(url, headers={'User-Agent': 'Mozilla/5.0'})
    soup = BeautifulSoup(response.text, 'html.parser')

    blogs = soup.find_all('div', class_='fl-post-column')
    results = []

    for blog in blogs:
        title = blog.find('h2', class_='fl-post-grid-title').get_text(strip=True)
        link = blog.find('a', rel='bookmark')['href']
        date = blog.find('span', class_='fl-post-grid-date').get_text(strip=True)
        image = blog.find('img')['src']
        
        results.append({
            'title': title,
            'link': link,
            'date': date,
            'image': image,
        })

    return results

# Hàm xử lý pagination
def scrape_all_blogs(base_url):
    all_blogs = []
    next_page = base_url

    while next_page:
        print(f"Scraping: {next_page}")
        blogs = scrape_blog_page(next_page)
        all_blogs.extend(blogs)
        
        # Tìm link tới trang kế tiếp (pagination)
        response = requests.get(next_page, headers={'User-Agent': 'Mozilla/5.0'})
        soup = BeautifulSoup(response.text, 'html.parser')
        next_page_tag = soup.find('a', class_='next page-numbers')
        next_page = next_page_tag['href'] if next_page_tag else None

    return all_blogs

# URL gốc
start_url = 'https://newbreak.church/blog/?gad_source=1&gclid=Cj0KCQiA7NO7BhDsARIsADg_hIb6THWfJcUdxD9HMXljPV1Vyxk0JRYy_zhQUtnw8Hmr-s6GB19FuZAaAmuIEALw_wcB'
blogs = scrape_all_blogs(start_url)

# In kết quả
for blog in blogs:
    print(blog)
# Out:
# Scraping: https://newbreak.church/blog/?gad_source=1&gclid=Cj0KCQiA7NO7BhDsARIsADg_hIb6THWfJcUdxD9HMXljPV1Vyxk0JRYy_zhQUtnw8Hmr-s6GB19FuZAaAmuIEALw_wcB
# Scraping: https://newbreak.church/blog/page/2/?gad_source=1
# Scraping: https://newbreak.church/blog/page/3/?gad_source=1
# Scraping: https://newbreak.church/blog/page/4/?gad_source=1
# Scraping: https://newbreak.church/blog/page/5/?gad_source=1
# Scraping: https://newbreak.church/blog/page/6/?gad_source=1
# Scraping: https://newbreak.church/blog/page/7/?gad_source=1
# Scraping: https://newbreak.church/blog/page/8/?gad_source=1
# Scraping: https://newbreak.church/blog/page/9/?gad_source=1
# Scraping: https://newbreak.church/blog/page/10/?gad_source=1
# Scraping: https://newbreak.church/blog/page/11/?gad_source=1
# Scraping: https://newbreak.church/blog/page/12/?gad_source=1
# Scraping: https://newbreak.church/blog/page/13/?gad_source=1
# Scraping: https://newbreak.church/blog/page/14/?gad_source=1
# Scraping: https://newbreak.church/blog/page/15/?gad_source=1
# Scraping: https://newbreak.church/blog/page/16/?gad_source=1
# {'title': 'You Are Under Construction', 'link': 'https://newbreak.church/article-you-are-under-construction/', 'date': 'June 10, 2024', 'image': 'https://newbreak.church/wp-content/uploads/2024/06/t5yuohw6zro-1024x683.jpg'}
# {'title': 'Jesus at the Center', 'link': 'https://newbreak.church/article-jesus-at-the-center/', 'date': 'June 3, 2024', 'image': 'https://newbreak.church/wp-content/uploads/2024/05/kfvmyjk6hz8-1024x701.jpg'}
# {'title': 'Let’s Grow', 'link': 'https://newbreak.church/lets-grow/', 'date': 'May 27, 2024', 'image': 'https://newbreak.church/wp-content/uploads/2024/05/ticsucsxms4-1024x683.jpg'}
# {'title': 'Praying God-Sized Prayers', 'link': 'https://newbreak.church/praying-god-sized-prayers/', 'date': 'May 20, 2024', 'image': 'https://newbreak.church/wp-content/uploads/2024/05/lpcu8hngu2e-1024x740.jpg'}
# {'title': 'The Ephesians Test', 'link': 'https://newbreak.church/the-ephesians-test/', 'date': 'May 9, 2024', 'image': 'https://newbreak.church/wp-content/uploads/2024/04/bexuizvxw-q-1024x683.jpg'}
# {'title': 'Finding Purpose in Your Pain', 'link': 'https://newbreak.church/finding-purpose-in-your-pain/', 'date': 'April 17, 2024', 'image': 'https://newbreak.church/wp-content/uploads/2024/04/bexuizvxw-q-1024x683.jpg'}
# {'title': 'The Gospel and Baseball', 'link': 'https://newbreak.church/the-gospel-and-baseball/', 'date': 'April 9, 2024', 'image': 'https://newbreak.church/wp-content/uploads/2024/04/vohpkm7ruoq-1024x819.jpg'}
# {'title': 'Set Apart for a Purpose', 'link': 'https://newbreak.church/set-apart-for-a-purpose/', 'date': 'March 25, 2024', 'image': 'https://newbreak.church/wp-content/uploads/2024/03/evo4wmtrapi-1024x625.jpg'}
# {'title': 'When You’re Disconnecting from God', 'link': 'https://newbreak.church/when-youre-disconnecting-from-god/', 'date': 'March 18, 2024', 'image': 'https://newbreak.church/wp-content/uploads/2024/03/nvlcsizedm0-1024x644.jpg'}
# {'title': 'The church’s secret weapon.', 'link': 'https://newbreak.church/the-churchs-secret-weapon/', 'date': 'March 12, 2024', 'image': 'https://newbreak.church/wp-content/uploads/2024/03/tammbr4okv4-1024x684.jpg'}
# {'title': 'Jesus Speaks Life Into The Dead Places', 'link': 'https://newbreak.church/jesus-speaks-life-into-the-dead-places/', 'date': 'March 4, 2024', 'image': 'https://newbreak.church/wp-content/uploads/2024/03/4hwflpg54ea-1024x683.jpg'}
# {'title': 'How to Listen for the Voice of Jesus', 'link': 'https://newbreak.church/how-to-listen-for-the-voice-of-jesus/', 'date': 'February 26, 2024', 'image': 'https://newbreak.church/wp-content/uploads/2024/02/tmxju4cgsna-1024x578.jpg'}
# {'title': 'God of Miracles', 'link': 'https://newbreak.church/god-of-miracles/', 'date': 'February 14, 2024', 'image': 'https://newbreak.church/wp-content/uploads/2024/02/hs5clnqbcoc-1024x683.jpg'}
# {'title': 'Vision without Execution is Hallucination', 'link': 'https://newbreak.church/vision-without-execution-is-hallucination/', 'date': 'February 6, 2024', 'image': 'https://newbreak.church/wp-content/uploads/2024/02/tub9a0rb04k-1024x677.jpg'}
# {'title': 'Jesus Wants to Meet You', 'link': 'https://newbreak.church/jesus-wants-to-meet-you/', 'date': 'January 29, 2024', 'image': 'https://newbreak.church/wp-content/uploads/2024/01/fkddmpkvv9u-1024x683.jpg'}
# {'title': 'What the Wind and the Holy Spirit Have in Common (and Why it Matters!)', 'link': 'https://newbreak.church/what-the-wind-and-the-holy-spirit-have-in-common-and-why-it-matters/', 'date': 'January 22, 2024', 'image': 'https://newbreak.church/wp-content/uploads/2024/01/fcqkpoutywi-1024x683.jpg'}
# {'title': 'What do you do when your wine runs out?', 'link': 'https://newbreak.church/what-do-you-do-when-your-wine-runs-out/', 'date': 'January 15, 2024', 'image': 'https://newbreak.church/wp-content/uploads/2024/01/udj2td3wksy-1024x683.jpg'}
# {'title': 'Who is Jesus?', 'link': 'https://newbreak.church/who-is-jesus/', 'date': 'January 8, 2024', 'image': 'https://newbreak.church/wp-content/uploads/2024/01/qdp10nbwcye-1024x777.jpg'}
# {'title': 'Holding onto God’s Promises', 'link': 'https://newbreak.church/holding-onto-gods-promises/', 'date': 'January 1, 2024', 'image': 'https://newbreak.church/wp-content/uploads/2023/12/paykyb-8er8-1024x684.jpg'}
# {'title': 'The Serious Business of Heaven', 'link': 'https://newbreak.church/the-serious-business-of-heaven/', 'date': 'December 18, 2023', 'image': 'https://newbreak.church/wp-content/uploads/2023/12/rokbmubcovg-1024x683.jpg'}
# {'title': 'Juggling Worry', 'link': 'https://newbreak.church/juggling-worry/', 'date': 'December 14, 2023', 'image': 'https://newbreak.church/wp-content/uploads/2023/12/bwktz4yvtma-1024x684.jpg'}
# {'title': 'An Announcement from Newbreak’s Board of Elders Regarding the Wachs’ Resignation', 'link': 'https://newbreak.church/an-announcement-from-newbreaks-board-of-elders-regarding-the-wachs-resignation/', 'date': 'November 30, 2023', 'image': 'https://newbreak.church/wp-content/uploads/2023/05/Newbreak-Church-Tierrasata-Campus-Hero-1024x683.jpg'}
# {'title': 'Robert Wachs’ Resignation', 'link': 'https://newbreak.church/robert-wachs-resignation/', 'date': 'November 29, 2023', 'image': 'https://newbreak.church/wp-content/uploads/2023/11/Robert-Wachs-scaled-web-1024x597.jpg'}
# {'title': '“God, Just Tell Me What to Do Next!”', 'link': 'https://newbreak.church/holy-spirit-guidance/', 'date': 'November 6, 2023', 'image': 'https://newbreak.church/wp-content/uploads/2023/11/i0iarfzfjzm-1024x683.jpg'}
# {'title': 'Pregnancy Loss', 'link': 'https://newbreak.church/pregnancy-loss/', 'date': 'April 4, 2023', 'image': 'https://newbreak.church/wp-content/uploads/2023/04/ymtdjv7jkpi-1024x683.jpg'}
# {'title': 'You Are Not Just Talented, You Are Spiritually Gifted', 'link': 'https://newbreak.church/spiritually-gifted/', 'date': 'February 11, 2023', 'image': 'https://newbreak.church/wp-content/uploads/2023/02/3kv48ns4wuu-1024x683.jpg'}
# {'title': 'A Lesson in Reading the “Commands” of Scripture', 'link': 'https://newbreak.church/reading-commands/', 'date': 'January 14, 2023', 'image': 'https://newbreak.church/wp-content/uploads/2023/02/xqxjjhk-c08-1024x683.jpg'}
# {'title': 'Living with Purpose', 'link': 'https://newbreak.church/living-with-purpose/', 'date': 'January 12, 2023', 'image': 'https://newbreak.church/wp-content/uploads/2023/01/Living-With-Purpose-Title-1024x576.jpg'}
# {'title': 'You Were Loved Into Existence', 'link': 'https://newbreak.church/loved-into-existence/', 'date': 'January 7, 2023', 'image': 'https://newbreak.church/wp-content/uploads/2023/01/abkeaojny0s-1024x683.jpg'}
# {'title': 'Bible Verses to Ground Your Day in Gratitude', 'link': 'https://newbreak.church/thanksgiving-verses/', 'date': 'November 19, 2022', 'image': 'https://newbreak.church/wp-content/uploads/2022/11/p2oqw69vxp4-1024x636.jpg'}
# {'title': 'Be Busy, Not Hurried', 'link': 'https://newbreak.church/busy-not-hurried/', 'date': 'November 12, 2022', 'image': 'https://newbreak.church/wp-content/uploads/2022/11/by34glow7wa-1024x683.jpg'}
# {'title': '5 Things You Can Do TODAY to Improve Your Communication!', 'link': 'https://newbreak.church/5-communication-tools/', 'date': 'October 22, 2022', 'image': 'https://newbreak.church/wp-content/uploads/2022/10/kpwrdhbq2qs-1024x577.jpg'}
# {'title': 'How the Church is More Like an Amateur Children’s Play Than a Show on Broadway', 'link': 'https://newbreak.church/messy-church/', 'date': 'October 8, 2022', 'image': 'https://newbreak.church/wp-content/uploads/2022/10/ww1jsinxgwm-1024x684.jpg'}
# {'title': 'What If You Never Understand Why You Went Through That Unbearably Painful Circumstance?', 'link': 'https://newbreak.church/suffering-without-answers/', 'date': 'September 24, 2022', 'image': 'https://newbreak.church/wp-content/uploads/2022/09/bunwp1bl0nc-1024x668.jpg'}
# {'title': 'What If the Church Was a Family?', 'link': 'https://newbreak.church/church-as-family/', 'date': 'September 3, 2022', 'image': 'https://newbreak.church/wp-content/uploads/2022/08/wnvnnhhcbem-1024x683.jpg'}
# {'title': 'What We Can Learn from the Liturgy of Seasons', 'link': 'https://newbreak.church/liturgy-of-seasons/', 'date': 'August 26, 2022', 'image': 'https://newbreak.church/wp-content/uploads/2022/08/gao0yp-mj_m-1024x678.jpg'}
# {'title': 'Redeeming Our Regrets', 'link': 'https://newbreak.church/regret/', 'date': 'August 15, 2022', 'image': 'https://newbreak.church/wp-content/uploads/2022/08/kq3mxxdgeom-1024x683.jpg'}
# {'title': 'Combatting Complacency So I Press On Toward All God Has For Me', 'link': 'https://newbreak.church/combatting-complacency/', 'date': 'July 28, 2022', 'image': 'https://newbreak.church/wp-content/uploads/2022/07/nhrjqkriute-1024x683.jpg'}
# {'title': 'How to Pray a Blessing Over Your Kids', 'link': 'https://newbreak.church/praying-blessing/', 'date': 'July 9, 2022', 'image': 'https://newbreak.church/wp-content/uploads/2022/07/mcxesld2su-1024x683.jpg'}
# {'title': '3 Ways to Express Affirmation to Others (But Especially Your Kids!)', 'link': 'https://newbreak.church/affirmation/', 'date': 'June 18, 2022', 'image': 'https://newbreak.church/wp-content/uploads/2022/06/cifarlz4wvk-1024x682.jpg'}
# {'title': 'Who Do We Trust: Almighty God or the Almighty Dollar?', 'link': 'https://newbreak.church/in-god-we-trust/', 'date': 'June 6, 2022', 'image': 'https://newbreak.church/wp-content/uploads/2022/06/jw6r_0cpyec-1024x683.jpg'}
# {'title': 'Uprooting the “Strongholds” in Our Mind', 'link': 'https://newbreak.church/uprooting-strongholds/', 'date': 'May 19, 2022', 'image': 'https://newbreak.church/wp-content/uploads/2022/05/do1i_fwbbcw-1024x768.jpg'}
# {'title': 'What Gave the Israelites the Right to “Invade” Canaan?', 'link': 'https://newbreak.church/israel-conquest/', 'date': 'March 9, 2022', 'image': 'https://newbreak.church/wp-content/uploads/2022/03/wrynphvpx4q-1024x768.jpg'}
# {'title': 'How God’s Joy is Better Than Instant Gratification', 'link': 'https://newbreak.church/lasting-joy/', 'date': 'February 22, 2022', 'image': 'https://newbreak.church/wp-content/uploads/2022/02/6emneh4p8la-1024x683.jpg'}
# {'title': 'Where Was Jesus Before the Gospels?', 'link': 'https://newbreak.church/theophany/', 'date': 'February 8, 2022', 'image': 'https://newbreak.church/wp-content/uploads/2022/02/ecize6mduh8-1024x685.jpg'}
# {'title': 'Made For More Than Manna', 'link': 'https://newbreak.church/manna/', 'date': 'February 4, 2022', 'image': 'https://newbreak.church/wp-content/uploads/2022/02/cnktbizjicw-1024x685.jpg'}
# {'title': 'Where Does Courage Come From?', 'link': 'https://newbreak.church/courage/', 'date': 'January 14, 2022', 'image': 'https://newbreak.church/wp-content/uploads/2022/01/ioic2yh4xlu-1024x819.jpg'}
# {'title': 'The Gates of Hell or Hades? What’s the Difference?', 'link': 'https://newbreak.church/gates-of-hades/', 'date': 'December 3, 2021', 'image': 'https://newbreak.church/wp-content/uploads/2021/12/eiwvoa9zb10-1024x683.jpg'}
# {'title': 'When We Look Like Our Heavenly Father', 'link': 'https://newbreak.church/when-we-look-like-our-heavenly-father/', 'date': 'October 16, 2021', 'image': 'https://newbreak.church/wp-content/uploads/2021/10/hs_egxljozs-1024x683.jpg'}
# {'title': 'Newbreak Church is Committed to Tierrasanta', 'link': 'https://newbreak.church/newbreak-church-is-committed-to-tierrasanta/', 'date': 'September 14, 2021', 'image': 'https://newbreak.church/wp-content/uploads/2021/07/j_community_tierrasanta-1024x683.jpg'}
# {'title': 'Happy Are the Unhappy', 'link': 'https://newbreak.church/happy-are-the-unhappy/', 'date': 'September 10, 2021', 'image': 'https://newbreak.church/wp-content/uploads/2021/09/ieev01cucy0-1024x726.jpg'}
# {'title': 'The Hidden Surprise in the Story of Mary and Martha', 'link': 'https://newbreak.church/cultural-context/', 'date': 'August 3, 2021', 'image': 'https://newbreak.church/wp-content/uploads/2021/08/phigyugqpvu-1024x683.jpg'}
# {'title': '5 Insights on Relationships from the Past Two Years', 'link': 'https://newbreak.church/5-insights-on-relationships/', 'date': 'July 30, 2021', 'image': 'https://newbreak.church/wp-content/uploads/2021/07/khstxrvhfog-1024x768.jpg'}
# {'title': 'Community > Individualism', 'link': 'https://newbreak.church/community-individualism/', 'date': 'July 23, 2021', 'image': 'https://newbreak.church/wp-content/uploads/2021/08/becc0nyip2g-1024x809.jpg'}
# {'title': 'Reframing the Question We Ask Every Kid', 'link': 'https://newbreak.church/reframing-the-question/', 'date': 'July 15, 2021', 'image': 'https://newbreak.church/wp-content/uploads/2021/07/ov44gxh71du-1024x683.jpg'}
# {'title': 'The Power of Prepositions', 'link': 'https://newbreak.church/the-power-of-prepositions/', 'date': 'July 9, 2021', 'image': 'https://newbreak.church/wp-content/uploads/2021/07/ronxy5sidhw-1024x683.jpg'}
# {'title': 'The Scientific Benefits of Gratitude', 'link': 'https://newbreak.church/the-scientific-benefits-of-gratitude/', 'date': 'July 2, 2021', 'image': 'https://newbreak.church/wp-content/uploads/2021/08/p22zbyw3gio-1024x683.jpg'}
# {'title': 'The Small Shift that Can Make a Big Difference for Your Kids', 'link': 'https://newbreak.church/small-shift-big-difference/', 'date': 'June 17, 2021', 'image': 'https://newbreak.church/wp-content/uploads/2021/06/7edwo30e32k-1024x683.jpg'}
# {'title': 'The Secret Ingredient of Endurance', 'link': 'https://newbreak.church/the-secret-ingredient-of-endurance/', 'date': 'June 10, 2021', 'image': 'https://newbreak.church/wp-content/uploads/2021/06/xv4l_bb0z_8-1024x683.jpg'}
# {'title': 'Learning Leadership Lessons from Rabbi Jesus', 'link': 'https://newbreak.church/leadership-lessons-from-jesus/', 'date': 'June 4, 2021', 'image': 'https://newbreak.church/wp-content/uploads/2021/06/z0nvqfroqwa-1024x683.jpg'}
# {'title': 'What If We Miss How God Wants Us to Prosper?', 'link': 'https://newbreak.church/when-prospering-looks-different/', 'date': 'May 27, 2021', 'image': 'https://newbreak.church/wp-content/uploads/2021/05/xbxqzlnbm0q-1024x683.jpg'}
# {'title': 'Be All That You Can Be', 'link': 'https://newbreak.church/be-all-that-you-can-be/', 'date': 'May 22, 2021', 'image': 'https://newbreak.church/wp-content/uploads/2021/05/u-g-F5JYEF0.jpg'}
# {'title': 'Why Jesus Cares So Much About Our “Eyes”', 'link': 'https://newbreak.church/evil-eye/', 'date': 'May 14, 2021', 'image': 'https://newbreak.church/wp-content/uploads/2021/05/g1iycecw2ei-1024x684.jpg'}
# {'title': '3 Things I Wish I Knew as a Newer Mom', 'link': 'https://newbreak.church/newer-mom/', 'date': 'May 8, 2021', 'image': 'https://newbreak.church/wp-content/uploads/2021/05/pmnjs6b3xp4-1024x683.jpg'}
# {'title': 'Have You Considered the Flowers?', 'link': 'https://newbreak.church/have-you-considered-the-flowers/', 'date': 'May 1, 2021', 'image': 'https://newbreak.church/wp-content/uploads/2021/04/flowers-of-the-field-Ariana-Photo.jpeg'}
# {'title': 'How You Are Free From Sin', 'link': 'https://newbreak.church/how-you-are-free-from-sin/', 'date': 'April 24, 2021', 'image': 'https://newbreak.church/wp-content/uploads/2021/04/riuzqofq8xe-1024x601.jpg'}
# {'title': 'Matthew 20: A Lesson on How to Read the Parables of Jesus', 'link': 'https://newbreak.church/matthew-20-a-lesson-on-how-to-read-the-parables-of-jesus/', 'date': 'April 17, 2021', 'image': 'https://newbreak.church/wp-content/uploads/2021/04/tjknag4ryz0-1024x819.jpg'}
# {'title': 'Newbreak Church is providing clean water for the entire Namosi province of Fiji.', 'link': 'https://newbreak.church/newbreak-church-is-providing-clean-water-for-the-entire-namosi-province-of-fiji/', 'date': 'April 16, 2021', 'image': 'https://newbreak.church/wp-content/uploads/2021/04/Fiji_Newbreak_Church.png'}
# {'title': 'From Spending to Investing: Changing the Way We See Time', 'link': 'https://newbreak.church/from-spending-to-investing-changing-the-way-we-see-time/', 'date': 'March 27, 2021', 'image': 'https://newbreak.church/wp-content/uploads/2021/03/bxoxnq26b7o-1024x683.jpg'}
# {'title': 'Why Do I Need the Holy Spirit to Talk About Jesus?', 'link': 'https://newbreak.church/why-do-i-need-the-holy-spirit-to-talk-about-jesus/', 'date': 'March 20, 2021', 'image': 'https://newbreak.church/wp-content/uploads/2021/03/bvpkyuviwwq-1024x683.jpg'}
# {'title': 'When the Ink of Scripture Spills Over Into Our Lives', 'link': 'https://newbreak.church/god-stories-are-happening-all-the-time/', 'date': 'March 13, 2021', 'image': 'https://newbreak.church/wp-content/uploads/2021/03/oyrqisvcmli-1024x684.jpg'}
# {'title': 'We Are Called to Be Storytellers!', 'link': 'https://newbreak.church/we-are-storytellers/', 'date': 'March 6, 2021', 'image': 'https://newbreak.church/wp-content/uploads/2021/03/kdeqa3atnby-1024x683.jpg'}
# {'title': 'Kingdom Builders Funds People and Projects Around the World', 'link': 'https://newbreak.church/kingdom-builders-funds-people-and-projects-around-the-world/', 'date': 'March 4, 2021', 'image': 'https://newbreak.church/wp-content/uploads/2021/03/Kingdom-Builders-Kids.jpg'}
# {'title': 'What It Means to “Honor” One Another', 'link': 'https://newbreak.church/what-it-means-to-honor-one-another/', 'date': 'February 27, 2021', 'image': 'https://newbreak.church/wp-content/uploads/2021/02/awidiboro08-1024x684.jpg'}
# {'title': 'Leading Your Home Around Personalized, Christ-Centered Values', 'link': 'https://newbreak.church/leading-your-home-around-values/', 'date': 'February 19, 2021', 'image': 'https://newbreak.church/wp-content/uploads/2021/02/zf_ptlx_dkg-1024x683.jpg'}
# {'title': 'Give Clean Water and Kingdom Builders', 'link': 'https://newbreak.church/give-clean-water-and-kingdom-builders/', 'date': 'February 19, 2021', 'image': 'https://newbreak.church/wp-content/uploads/2021/02/IMG_1804_2-1024x768.jpg'}
# {'title': 'Eden Was Just the Beginning of God’s Plan', 'link': 'https://newbreak.church/eden-was-just-the-beginning/', 'date': 'February 12, 2021', 'image': 'https://newbreak.church/wp-content/uploads/2021/02/95lwbb9wtg4-1024x683.jpg'}
# {'title': 'It’s More Than a Water Project… It’s a People Project!', 'link': 'https://newbreak.church/its-more-than-a-water-project-its-a-people-project/', 'date': 'February 6, 2021', 'image': 'https://newbreak.church/wp-content/uploads/2021/02/image3-768x1024.jpeg'}
# {'title': 'Waltzing Our Way into More Spiritual Fruit', 'link': 'https://newbreak.church/fruit-of-the-spirit/', 'date': 'January 28, 2021', 'image': 'https://newbreak.church/wp-content/uploads/2021/01/nkwxb8egzo0-684x1024.jpg'}
# {'title': 'The Power of Memorizing Scripture', 'link': 'https://newbreak.church/memorizing-scripture/', 'date': 'January 19, 2021', 'image': 'https://newbreak.church/wp-content/uploads/2021/01/jku2nnezabi-1024x683.jpg'}
# {'title': 'Why Sabbath is Way More Powerful Than a “Day Off”', 'link': 'https://newbreak.church/sabbath/', 'date': 'January 14, 2021', 'image': 'https://newbreak.church/wp-content/uploads/2021/01/cgyrwbe6hm4-1024x576.jpg'}
# {'title': 'We are Committed to Ocean Beach', 'link': 'https://newbreak.church/we-are-committed-to-ocean-beach/', 'date': 'January 11, 2021', 'image': 'https://newbreak.church/wp-content/uploads/2021/08/20170128_162912_hdr-1024x515.jpg'}
# {'title': 'How is the Pace of Your Life?', 'link': 'https://newbreak.church/how-is-the-pace-of-your-life/', 'date': 'January 10, 2021', 'image': 'https://newbreak.church/wp-content/uploads/2021/01/ljocgjs63sm-1024x683.jpg'}
# {'title': 'Setting Some Spiritual Goals for 2021', 'link': 'https://newbreak.church/setting-some-spiritual-goals-for-2021/', 'date': 'January 3, 2021', 'image': 'https://newbreak.church/wp-content/uploads/2020/12/iulgi9pwetu-1024x683.jpg'}
# {'title': 'How Memory Cultivates Courage', 'link': 'https://newbreak.church/how-memory-cultivates-courage/', 'date': 'December 27, 2020', 'image': 'https://newbreak.church/wp-content/uploads/2020/12/obpce_x3j6u-1024x683.jpg'}
# {'title': '“Prince of Peace,” A Perplexing Title For Jesus', 'link': 'https://newbreak.church/sar-shalom-a-perplexing-title-for-jesus/', 'date': 'December 20, 2020', 'image': 'https://newbreak.church/wp-content/uploads/2020/12/dcqvwkxf74q-1024x683.jpg'}
# {'title': 'Disrupting Our Distractions This Christmas', 'link': 'https://newbreak.church/disrupting-our-distractions-this-christmas/', 'date': 'December 13, 2020', 'image': 'https://newbreak.church/wp-content/uploads/2020/12/sutffcahv_a-1024x683.jpg'}
# {'title': 'How to Create a Lasting Legacy', 'link': 'https://newbreak.church/how-to-create-a-lasting-legacy/', 'date': 'December 11, 2020', 'image': 'https://newbreak.church/wp-content/uploads/2020/09/Mike-Quinn-1024x1024.jpg'}
# {'title': 'Who Was the Real St. Nick?', 'link': 'https://newbreak.church/who-was-the-real-st-nick/', 'date': 'December 6, 2020', 'image': 'https://newbreak.church/wp-content/uploads/2020/12/hodecggatuw-1024x683.jpg'}
# {'title': 'Christmas, Typology, and Binding the Bible Together', 'link': 'https://newbreak.church/jesus-typology-and-binding-the-bible-together/', 'date': 'November 29, 2020', 'image': 'https://newbreak.church/wp-content/uploads/2020/11/1-rl6usjcge-1024x681.jpg'}
# {'title': 'How Will They Hear If No One is Sent?', 'link': 'https://newbreak.church/how-will-they-hear-if-no-one-is-sent/', 'date': 'November 22, 2020', 'image': 'https://newbreak.church/wp-content/uploads/2020/11/8ml_m_bri-m-1024x763.jpg'}
# {'title': 'Looking Backward for Confidence to Move Forward with Courage', 'link': 'https://newbreak.church/looking-backward-for-confidence-to-move-forward-with-courage/', 'date': 'November 15, 2020', 'image': 'https://newbreak.church/wp-content/uploads/2020/11/xuxghzhibn4-1-1024x683.jpg'}
# {'title': 'Regardless of Who You Voted For…', 'link': 'https://newbreak.church/whose-faithfulness-do-you-have-faith-in/', 'date': 'November 8, 2020', 'image': 'https://newbreak.church/wp-content/uploads/2020/11/gdq_az6cspo-1024x683.jpg'}
# {'title': 'Trusting God with the Blank Spaces', 'link': 'https://newbreak.church/trusting-god-with-the-blank-spaces/', 'date': 'November 1, 2020', 'image': 'https://newbreak.church/wp-content/uploads/2020/10/o5xjoxrybqo-1024x683.jpg'}
# {'title': 'What Causes Disunity Among Christians?', 'link': 'https://newbreak.church/what-causes-disunity-among-christians/', 'date': 'October 25, 2020', 'image': 'https://newbreak.church/wp-content/uploads/2020/10/zs-pagqgenq.jpg'}
# {'title': 'The Difference Between Forgiveness and Trust', 'link': 'https://newbreak.church/the-difference-between-forgiveness-and-trust/', 'date': 'October 18, 2020', 'image': 'https://newbreak.church/wp-content/uploads/2020/10/ktpkyus3qjs-1024x684.jpg'}
# {'title': 'Should I Pray for the Desires of My Heart?', 'link': 'https://newbreak.church/should-i-pray-for-the-desires-of-my-heart/', 'date': 'October 11, 2020', 'image': 'https://newbreak.church/wp-content/uploads/2020/10/ynm4kstg78i-1024x683.jpg'}
# {'title': 'Why Prayer is So Much More Than Wish Lists', 'link': 'https://newbreak.church/why-prayer-is-so-more-than-wish-lists/', 'date': 'October 4, 2020', 'image': 'https://newbreak.church/wp-content/uploads/2020/09/nuo6itbkhxe-1024x683.jpg'}
# {'title': 'What is the Kingdom of God?', 'link': 'https://newbreak.church/what-is-the-kingdom-of-god/', 'date': 'September 27, 2020', 'image': 'https://newbreak.church/wp-content/uploads/2020/09/kp1bubr2j4a-1024x683.jpg'}
# {'title': 'If You Could Pray Like Elijah…', 'link': 'https://newbreak.church/if-you-could-pray-like-elijah/', 'date': 'September 20, 2020', 'image': 'https://newbreak.church/wp-content/uploads/2020/09/6liebveafry-1024x683.jpg'}
# {'title': 'The Key Ingredient That De-escalates Conflict', 'link': 'https://newbreak.church/the-key-ingredient-that-deescalates-conflict/', 'date': 'September 13, 2020', 'image': 'https://newbreak.church/wp-content/uploads/2020/09/hx7xdwhj2ay-1024x683.jpg'}
# {'title': 'What’s Guarding Your Mouth?', 'link': 'https://newbreak.church/whats-guarding-your-mouth/', 'date': 'September 6, 2020', 'image': 'https://newbreak.church/wp-content/uploads/2020/09/pompxtcvyho-1024x768.jpg'}
# {'title': 'How Faith and Works Complete Each Other', 'link': 'https://newbreak.church/how-paul-and-james-complement-each-other/', 'date': 'August 31, 2020', 'image': 'https://newbreak.church/wp-content/uploads/2020/08/at5vupoi8vc-683x1024.jpg'}
# {'title': 'The Secret to the Early Church’s Explosive Growth (It’s Not What You Think!)', 'link': 'https://newbreak.church/early-church-growth/', 'date': 'August 23, 2020', 'image': 'https://newbreak.church/wp-content/uploads/2020/08/axt4iycoi2m.jpg'}
# {'title': 'How to Make Sure Each Sermon You Listen to Makes a Lasting Impact!', 'link': 'https://newbreak.church/how-to-get-the-most-out-of-each-weeks-sermon/', 'date': 'August 16, 2020', 'image': 'https://newbreak.church/wp-content/uploads/2020/08/fmd_cru6otk-1024x683.jpg'}
# {'title': 'The Danger of Being “Double-Minded”', 'link': 'https://newbreak.church/the-danger-of-being-double-minded/', 'date': 'August 9, 2020', 'image': 'https://newbreak.church/wp-content/uploads/2020/07/nfqo34llcvy-1024x758.jpg'}
# {'title': 'What Does it Mean to “Fear the LORD”?', 'link': 'https://newbreak.church/what-does-it-mean-to-fear-the-lord/', 'date': 'August 2, 2020', 'image': 'https://newbreak.church/wp-content/uploads/2020/07/wzlsz9drlsi-1024x683.jpg'}
# {'title': 'What Does it Mean to “Meditate on Scripture”?', 'link': 'https://newbreak.church/meditation/', 'date': 'July 26, 2020', 'image': 'https://newbreak.church/wp-content/uploads/2020/07/yui5vfkhuzs-1024x646.jpg'}
# {'title': 'From Spiritual “Disciplines” to Spiritual “Delights”', 'link': 'https://newbreak.church/from-spiritual-disciplines-to-spiritual-delights/', 'date': 'July 19, 2020', 'image': 'https://newbreak.church/wp-content/uploads/2020/06/ynrndb-xtme-1024x683.jpg'}
# {'title': 'How Stargazing Connects Us with God', 'link': 'https://newbreak.church/how-stargazing-connects-us-with-god/', 'date': 'July 12, 2020', 'image': 'https://newbreak.church/wp-content/uploads/2020/06/0r_jdrqqvqw-1024x683.jpg'}
# {'title': '“Theology”: The Art of Knowing the One Who Knows You', 'link': 'https://newbreak.church/theology-and-the-art-of-knowing-the-one-who-knows-you/', 'date': 'July 5, 2020', 'image': 'https://newbreak.church/wp-content/uploads/2020/07/d6ksvt2xzqo-1024x768.jpg'}
# {'title': 'Jesus is Your Shepherd: It’s More Practical Than You Might Think!', 'link': 'https://newbreak.church/jesus-is-your-shepherd-its-more-practical-than-you-think/', 'date': 'June 29, 2020', 'image': 'https://newbreak.church/wp-content/uploads/2020/06/dgfm-1jj-k-1024x576.jpg'}
# {'title': 'Planted and Flourishing – How You Can Relate to Fruit Trees!', 'link': 'https://newbreak.church/planted-and-flourishing/', 'date': 'June 21, 2020', 'image': 'https://newbreak.church/wp-content/uploads/2020/06/s_r6kv1xihe-1024x678.jpg'}
# {'title': 'Unconditional Love Or Unconditional Approval?', 'link': 'https://newbreak.church/unconditional-love-or-unconditional-approval/', 'date': 'June 14, 2020', 'image': 'https://newbreak.church/wp-content/uploads/2020/05/jcc8sxk2adw-1024x575.jpg'}
# {'title': 'Pulling Planks: How to Judge Others According to Jesus', 'link': 'https://newbreak.church/pulling-planks-how-to-judge-others-according-to-jesus/', 'date': 'June 7, 2020', 'image': 'https://newbreak.church/wp-content/uploads/2020/05/ycdpu73kgsc-1024x683.jpg'}
# {'title': 'How Repentance is Like a GPS', 'link': 'https://newbreak.church/how-repentance-is-like-a-gps/', 'date': 'May 31, 2020', 'image': 'https://newbreak.church/wp-content/uploads/2020/05/ooci35aia3m-1024x683.jpg'}
# {'title': 'Putting the “Shelter” into “Shelter-in-Place”', 'link': 'https://newbreak.church/putting-the-shelter-into-shelter-in-place/', 'date': 'May 24, 2020', 'image': 'https://newbreak.church/wp-content/uploads/2019/11/Amor_1.jpg'}
# {'title': 'When Attenders Become Contenders', 'link': 'https://newbreak.church/when-church-attenders-become-contenders/', 'date': 'May 15, 2020', 'image': 'https://newbreak.church/wp-content/uploads/2020/05/mo9vkbg5csg-1024x684.jpg'}
# {'title': 'How Do I Overcome Recurring Negative Thoughts?', 'link': 'https://newbreak.church/how-do-i-overcome-recurring-negative-thoughts/', 'date': 'May 8, 2020', 'image': 'https://newbreak.church/wp-content/uploads/2020/04/wkfq5bcsk3u-1024x683.jpg'}
# {'title': 'Can’t Sleep? Try This (It’s Better Than Counting Sheep!)', 'link': 'https://newbreak.church/cant-sleep-try-this-its-better-than-counting-sheep/', 'date': 'May 4, 2020', 'image': 'https://newbreak.church/wp-content/uploads/2020/04/ffzjspuwc_i-1024x683.jpg'}
# {'title': 'He Guards You Even While You Sleep', 'link': 'https://newbreak.church/he-guards-you-even-while-you-sleep/', 'date': 'April 24, 2020', 'image': 'https://newbreak.church/wp-content/uploads/2020/04/ve_un9v8xqu-1024x678.jpg'}
# {'title': 'In Times of Need Who Do You Call? (And Don’t Say “Ghost Busters”)', 'link': 'https://newbreak.church/in-times-of-need-who-do-you-call-and-dont-say-ghost-busters/', 'date': 'April 17, 2020', 'image': 'https://newbreak.church/wp-content/uploads/2020/04/h3gijctw__w-1024x683.jpg'}
# {'title': 'How Easter Speaks to the Problem of Suffering', 'link': 'https://newbreak.church/how-easter-speaks-to-the-problem-of-suffering/', 'date': 'April 10, 2020', 'image': 'https://newbreak.church/wp-content/uploads/2020/04/eivjakj1ucs-1024x684.jpg'}
# {'title': 'How Can God’s Heart Break?', 'link': 'https://newbreak.church/how-can-gods-heart-break/', 'date': 'April 3, 2020', 'image': 'https://newbreak.church/wp-content/uploads/2020/04/jmd3ws9lbcc-1024x683.jpg'}
# {'title': 'Legacy-Defining Moments Occur During Hardship', 'link': 'https://newbreak.church/legacy-defining-moments-occur-during-hardship/', 'date': 'March 30, 2020', 'image': 'https://newbreak.church/wp-content/uploads/2020/03/ttuzki1xdzk-1024x687.jpg'}
# {'title': 'Leading Your Home While Social Distancing', 'link': 'https://newbreak.church/leading-your-home-amidst-the-required-social-distancing/', 'date': 'March 24, 2020', 'image': 'https://newbreak.church/wp-content/uploads/2020/03/4l2ml8-mlug-1024x653.jpg'}
# {'title': 'How Can I Be The Church During A Crisis?', 'link': 'https://newbreak.church/how-can-i-be-the-church-during-a-crisis/', 'date': 'March 16, 2020', 'image': 'https://newbreak.church/wp-content/uploads/2020/03/jrszwmrd_ws-1024x683.jpg'}
# {'title': 'Suffering is Tough, But We Are Too!', 'link': 'https://newbreak.church/suffering/', 'date': 'March 7, 2020', 'image': 'https://newbreak.church/wp-content/uploads/2020/02/yle5cgmfujk-1024x683.jpg'}
# {'title': 'What Is Lent And What Am I Supposed To Do?', 'link': 'https://newbreak.church/what-is-lent/', 'date': 'March 2, 2020', 'image': 'https://newbreak.church/wp-content/uploads/2020/03/yr4n8o_3upc-1024x678.jpg'}
# {'title': 'Collaborating Together Despite Our Differences', 'link': 'https://newbreak.church/collaborating-together-despite-our-differences/', 'date': 'February 24, 2020', 'image': 'https://newbreak.church/wp-content/uploads/2020/02/g1kr4ozfoac-1024x683.jpg'}
# {'title': 'Jesus’ Advice on Resolving Conflict', 'link': 'https://newbreak.church/jesus-advice-on-resolving-conflict/', 'date': 'February 11, 2020', 'image': 'https://newbreak.church/wp-content/uploads/2020/01/e1dagormkik-1024x683.jpg'}
# {'title': 'Better Communication At Home', 'link': 'https://newbreak.church/better-communication-at-home/', 'date': 'February 10, 2020', 'image': 'https://newbreak.church/wp-content/uploads/2020/01/mg-hdjyipte-1024x683.jpg'}
# {'title': 'Healthy Relationships – How Much Connection Is Enough?', 'link': 'https://newbreak.church/healthy-relationships-how-much-connection-is-enough/', 'date': 'January 31, 2020', 'image': 'https://newbreak.church/wp-content/uploads/2020/01/ksdfplrjreg-1024x685.jpg'}
# {'title': 'How Am I A Witness 2000 Years After The Fact?', 'link': 'https://newbreak.church/how-am-i-a-witness-2000-years-after-the-fact/', 'date': 'January 25, 2020', 'image': 'https://newbreak.church/wp-content/uploads/2020/01/kslnvacfehs-1024x683.jpg'}
# {'title': 'How Pentecost Lights a Fire in the Disciples', 'link': 'https://newbreak.church/how-pentecost-lights-a-fire-in-the-disciples-witness/', 'date': 'January 20, 2020', 'image': 'https://newbreak.church/wp-content/uploads/2020/01/wuz2w2kucdu-1024x683.jpg'}
# {'title': 'What Makes the Difference in How We Process the Past?', 'link': 'https://newbreak.church/what-makes-the-difference-in-how-we-process-the-past/', 'date': 'January 13, 2020', 'image': 'https://newbreak.church/wp-content/uploads/2020/01/wozsluo_vak-1024x683.jpg'}
# {'title': 'New Beginnings In An Ongoing Story', 'link': 'https://newbreak.church/new-beginnings-in-an-ongoing-story/', 'date': 'January 6, 2020', 'image': 'https://newbreak.church/wp-content/uploads/2020/01/dwheufds6kq-1024x683.jpg'}

# %%
import requests
from bs4 import BeautifulSoup

# Gửi GET request
response = requests.get('https://www.nitrotechasia.com/')

# Kiểm tra nếu response thành công
if response.status_code == 200:
    # Parse HTML với BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # In tiêu đề trang
    print(soup.title.string)
    
    # Hoặc truy xuất các phần tử cụ thể
    for link in soup.find_all('a'):
        print(link.get('href'))
# Out:
# 2025-01-02 14:05:18 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): www.nitrotechasia.com:443
# 2025-01-02 14:05:19 [urllib3.connectionpool] DEBUG: https://www.nitrotechasia.com:443 "GET / HTTP/11" 200 None
# CÔNG TY TNHH NITRO TECH ASIA INC
# https://www.nitrotechasia.com
# #home
# #about
# #services
# #blog
# #info
# #contact
# https://www.nitrotechasia.com
# https://www.nitrotechasia.com?lang=jp
# #
# #
# #
# #
# #
# #
# https://www.facebook.com/photo.php?fbid=897887908734218&set=a.578872513969094&type=3&ref=embed_post
# https://www.facebook.com/photo.php?fbid=897887908734218&set=a.578872513969094&type=3&ref=embed_post
# https://www.facebook.com/photo.php?fbid=897887908734218&set=a.578872513969094&type=3&ref=embed_post
# https://www.facebook.com/watch/?v=286295107655119
# https://www.facebook.com/watch/?v=286295107655119
# https://www.facebook.com/watch/?v=286295107655119
# https://www.facebook.com/story.php?story_fbid=896686225521053&id=100055390520956&mibextid=I6gGtw
# https://www.facebook.com/story.php?story_fbid=896686225521053&id=100055390520956&mibextid=I6gGtw
# https://www.facebook.com/story.php?story_fbid=896686225521053&id=100055390520956&mibextid=I6gGtw
# https://www.designone.jp
# #danang
# #hue
# #gmail
# #messenger
# https://www.messenger.com/t/584304022080573
# #

# %%
import requests

# Gửi GET request
response = requests.get('https://www.mnot.net/blog/pinned.json')

# Kiểm tra nếu response thành công
if response.status_code == 200:
    # Parse dữ liệu JSON
    data = response.json()
    
    # In dữ liệu JSON dưới dạng dictionary
    print(data)
# Out:
# {'/blog/2024/04/29/power': {'path': '/blog/2024/04/29/power', 'hits': 401, 'visitors': 287, 'title': 'No One Should Have That Much Power', 'date': '29 April 2024'}, '/blog/2023/12/19/standards-and-centralization': {'path': '/blog/2023/12/19/standards-and-centralization', 'hits': 108, 'visitors': 105, 'title': 'RFC 9518 - What Can Internet Standards Do About Centralisation?', 'date': '19 December 2023'}, '/blog/2023/01/05/law-school': {'path': '/blog/2023/01/05/law-school', 'hits': 28, 'visitors': 27, 'title': 'What I Learned in Law School', 'date': ' 5 January 2023'}, '/blog/2022/06/08/http-extensions': {'path': '/blog/2022/06/08/http-extensions', 'hits': 53, 'visitors': 52, 'title': 'Yet More New HTTP Specs', 'date': ' 8 June 2022'}, '/blog/2022/06/06/http-core': {'path': '/blog/2022/06/06/http-core', 'hits': 90, 'visitors': 89, 'title': 'A New Definition of HTTP', 'date': ' 6 June 2022'}, '/blog/2020/08/28/for_the_users': {'path': '/blog/2020/08/28/for_the_users', 'hits': 98, 'visitors': 94, 'title': 'RFC 8890 - The Internet is for End Users', 'date': '28 August 2020'}, '/blog/2019/10/13/h2_api_multiplexing': {'path': '/blog/2019/10/13/h2_api_multiplexing', 'hits': 120, 'visitors': 114, 'title': 'How Multiplexing Changes Your HTTP APIs', 'date': '13 October 2019'}, '/blog/2019/06/11/endpoint_control': {'path': '/blog/2019/06/11/endpoint_control', 'hits': 35, 'visitors': 32, 'title': 'Moving Control to the Endpoints', 'date': '11 June 2019'}, '/blog/2018/11/27/header_compression': {'path': '/blog/2018/11/27/header_compression', 'hits': 141, 'visitors': 99, 'title': 'Designing Headers for HTTP Compression', 'date': '27 November 2018'}, '/blog/2018/07/31/read_rfc': {'path': '/blog/2018/07/31/read_rfc', 'hits': 120, 'visitors': 117, 'title': 'How to Read an RFC', 'date': '31 July 2018'}, '/blog/2017/05/11/status_codes': {'path': '/blog/2017/05/11/status_codes', 'hits': 112, 'visitors': 109, 'title': 'How to Think About HTTP Status Codes', 'date': '11 May 2017'}, '/blog/2017/03/16/browser-caching': {'path': '/blog/2017/03/16/browser-caching', 'hits': 335, 'visitors': 325, 'title': 'The State of Browser Caching, Revisited', 'date': '16 March 2017'}, '/blog/2014/12/04/what_is_the_web': {'path': '/blog/2014/12/04/what_is_the_web', 'hits': 61, 'visitors': 58, 'title': 'What is the Web?', 'date': ' 4 December 2014'}, '/blog/2014/06/07/rfc2616_is_dead': {'path': '/blog/2014/06/07/rfc2616_is_dead', 'hits': 181, 'visitors': 156, 'title': 'RFC2616 is Dead', 'date': ' 7 June 2014'}, '/blog/2013/06/23/linking_apis': {'path': '/blog/2013/06/23/linking_apis', 'hits': 30, 'visitors': 30, 'title': 'Five Reasons to Considering Linking in Your HTTP APIs', 'date': '23 June 2013'}, '/blog/2013/05/15/http_problem': {'path': '/blog/2013/05/15/http_problem', 'hits': 60, 'visitors': 56, 'title': 'Indicating Problems in HTTP APIs', 'date': '15 May 2013'}, '/blog/2012/12/04/api-evolution': {'path': '/blog/2012/12/04/api-evolution', 'hits': 126, 'visitors': 113, 'title': 'Evolving HTTP APIs', 'date': ' 4 December 2012'}, '/blog/2012/09/05/patch': {'path': '/blog/2012/09/05/patch', 'hits': 107, 'visitors': 102, 'title': 'Why PATCH is Good for Your HTTP API', 'date': ' 5 September 2012'}, '/blog/2012/07/11/header_versioning': {'path': '/blog/2012/07/11/header_versioning', 'hits': 24, 'visitors': 22, 'title': 'Bad HTTP API Smells: Version Headers', 'date': '11 July 2012'}, '/blog/2012/06/25/http_api_complexity_model': {'path': '/blog/2012/06/25/http_api_complexity_model', 'hits': 25, 'visitors': 24, 'title': 'HTTP API Complexity', 'date': '25 June 2012'}, '/blog/2011/11/25/linking_in_json': {'path': '/blog/2011/11/25/linking_in_json', 'hits': 229, 'visitors': 217, 'title': 'Linking in JSON', 'date': '25 November 2011'}, '/blog/2010/05/06/stale-controls': {'path': '/blog/2010/05/06/stale-controls', 'hits': 14, 'visitors': 14, 'title': 'RFC5861: HTTP Stale Controls', 'date': ' 6 May 2010'}, '/blog/2010/04/07/well-known': {'path': '/blog/2010/04/07/well-known', ...

# %%
import requests

# Gửi GET request để tải xuống hình ảnh
response = requests.get('https://hoanghamobile.com/tin-tuc/wp-content/uploads/2024/01/anh-nen-cute.jpg')

# Kiểm tra nếu response thành công
if response.status_code == 200:
    # Lưu hình ảnh vào tệp
    with open('downloaded_image.jpg', 'wb') as f:
        f.write(response.content)  # Ghi dữ liệu nhị phân vào tệp

# %%
from scrapy.crawler import CrawlerProcess
from scrapy import Spider
from scrapy.utils.project import get_project_settings

class PanigateSpider(Spider):
    name = 'panigate_spider'
    start_urls = ['https://truyenfull.io/the-loai/tien-hiep/']
    custom_settings = {
        'DEFAULT_REQUEST_HEADERS': {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.82 Safari/537.36'
        }
    }

    def parse(self, response):
        # Iterate through each book row
        for book in response.css('div.row'):
            title = book.css('h3.truyen-title a::text').get()
            author = book.css('span.author span.glyphicon-pencil + span::text').get()
            book_url = book.css('h3.truyen-title a::attr(href)').get()
            latest_chapter = book.css('div.col-xs-2 a::attr(href)').get()
            
            yield {
                'title': title,
                'author': author,
                'book_url': book_url,
                'latest_chapter': latest_chapter,
            }

        # Pagination handling
        next_page = response.css('li.next a::attr(href)').get()
        if next_page:
            yield response.follow(next_page, self.parse)

# Tạo hàm chạy Scrapy trong Notebook
def run_spider(spider):
    process = CrawlerProcess(get_project_settings())
    process.crawl(spider)
    process.start()

# Chạy spider
run_spider(PanigateSpider)
# Out:
# 2025-01-02 16:32:44 [scrapy.utils.log] INFO: Scrapy 2.11.2 started (bot: scrapybot)
# 2025-01-02 16:32:44 [scrapy.utils.log] INFO: Versions: lxml 5.3.0.0, libxml2 2.12.9, cssselect 1.2.0, parsel 1.9.1, w3lib 2.2.1, Twisted 24.7.0, Python 3.13.0 (v3.13.0:60403a5409f, Oct  7 2024, 00:37:40) [Clang 15.0.0 (clang-1500.3.9.4)], pyOpenSSL 24.2.1 (OpenSSL 3.3.2 3 Sep 2024), cryptography 43.0.3, Platform macOS-14.2-arm64-arm-64bit-Mach-O
# 2025-01-02 16:32:44 [scrapy.addons] INFO: Enabled addons:
# []
# 2025-01-02 16:32:44 [py.warnings] WARNING: /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scrapy/utils/request.py:254: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2025-01-02 16:32:44 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2025-01-02 16:32:44 [scrapy.extensions.telnet] INFO: Telnet Password: 1de2cc6298b7928c
# 2025-01-02 16:32:44 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2025-01-02 16:32:44 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2025-01-02 16:32:44 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2025-01-02 16:32:44 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2025-01-02 16:32:44 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2025-01-02 16:32:44 [scrapy.core.engine] INFO: Spider opened
# 2025-01-02 16:32:44 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2025-01-02 16:32:44 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6024
# 2025-01-02 16:32:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://truyenfull.io/the-loai/tien-hiep/> (referer: None)
# 2025-01-02 16:32:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://truyenfull.io/the-loai/tien-hiep/>
# {'title': None, 'author': None, 'book_url': None, 'latest_chapter': None}
# 2025-01-02 16:32:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://truyenfull.io/the-loai/tien-hiep/>
# {'title': 'Bá Chủ Thiên Hạ - Phong Thần', 'author': None, 'book_url': 'https://truyenfull.io/ba-chu-thien-ha-phong-than/', 'latest_chapter': 'https://truyenfull.io/ba-chu-thien-ha-phong-than/chuong-747/'}
# 2025-01-02 16:32:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://truyenfull.io/the-loai/tien-hiep/>
# {'title': 'Tình Hữu Độc Chung - Bất Tưởng Thượng Ban 2333', 'author': None, 'book_url': 'https://truyenfull.io/tinh-huu-doc-chung-bat-tuong-thuong-ban-2333/', 'latest_chapter': 'https://truyenfull.io/tinh-huu-doc-chung-bat-tuong-thuong-ban-2333/chuong-14/'}
# 2025-01-02 16:32:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://truyenfull.io/the-loai/tien-hiep/>
# {'title': 'Tướng Công Ta Đây Không Muốn Bị Ép Cưới', 'author': None, 'book_url': 'https://truyenfull.io/tuong-cong-ta-day-khong-muon-bi-ep-cuoi/', 'latest_chapter': 'https://truyenfull.io/tuong-cong-ta-day-khong-muon-bi-ep-cuoi/chuong-869/'}
# 2025-01-02 16:32:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://truyenfull.io/the-loai/tien-hiep/>
# {'title': 'Ai Tu Tiên Được Rồi Còn Làm Nữ Phụ Ác Độc Nữa Chứ', 'author': None, 'book_url': 'https://truyenfull.io/ai-tu-tien-duoc-roi-con-lam-nu-phu-ac-doc-nua-chu/', 'latest_chapter': 'https://truyenfull.io/ai-tu-tien-duoc-roi-con-lam-nu-phu-ac-doc-nua-chu/chuong-32/'}
# 2025-01-02 16:32:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://truyenfull.io/the-loai/tien-hiep/>
# {'title': 'Những Năm Ta Làm Mạnh Bà', 'author': None, 'book_url': 'https://truyenfull.io/nhung-nam-ta-lam-manh-ba/', 'latest_chapter': 'https://truyenfull.io/nhung-nam-ta-lam-manh-ba/chuong-70/'}
# 2025-01-02 16:32:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://truyenfull.io/the-loai/tien-hiep/>
# {'title': None, 'author': None, 'book_url': None, 'latest_chapter': None}
# 2025-01-02 16:32:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://truyenfull.io/the-loai/tien-hiep/>
# {'title': 'Nghe Nói Ta Sẽ Chết Trên Tay Nàng', 'author': None, 'book_url': 'https://truyenfull.io/nghe-noi-ta-se-chet-tren-tay-nang/', 'latest_chapter': 'https://truyenfull.io/nghe-noi-ta-se-chet-tren-tay-nang/chuong-22/'}
# 2025-01-02 16:32:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://truyenfull.io/the-loai/tien-hiep/>
# {'title': 'Bị Ép Làm Hôn Phu Của Kiếm Thánh', 'author': None, 'book_url': 'https://truyenfull.io/bi-ep-lam-hon-phu-cua-kiem-thanh/', 'latest_chapter': 'https://truyenfull.io/bi-ep-lam-hon-phu-cua-kiem-thanh/chuong-569/'}
# 2025-01-02 16:32:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://truyenfull.io/the-loai/tien-hiep/>
# {'title': 'Cửu Thiên Kiếm - SS Hà Thần', 'author': None, 'book_url': 'https://truyenfull.io/cuu-thien-kiem-ss-ha-than/', 'latest_chapter': 'https://truyenfull.io/cuu-thien-kiem-ss-ha-than/chuong-1146/'}
# 2025-01-02 16:32:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://truyenfull.io/the-loai/tien-hiep/>
# {'title': 'Tiểu Nữ Tử A Trúc/Tiểu Sư Muội Nói Chuyện Thần Kinh Cũng Là Thần', 'author': None, 'book_url': 'https://truyenfull.io/tieu-nu-tu-a-tructieu-su-muoi-noi-chuyen-than-kinh-cung-la-than/', 'latest_chapter': 'https://truyenfull.io/tieu-nu-tu-a-tructieu-su-muoi-noi-chuyen-than-kinh-cung-la-than/chuong-60/'}
# 2025-01-02 16:32:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://truyenfull.io/the-loai/tien-hiep/>
# {'title': 'Cuộc Sống Làm Nông Của Tống Đàm', 'author': None, 'book_url': 'https://truyenfull.io/cuoc-song-lam-nong-cua-tong-dam/', 'latest_chapter': 'https://truyenfull.io/cuoc-song-lam-nong-cua-tong-dam/chuong-250/'}
# 2025-01-02 16:32:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://truyenfull.io/the-loai/tien-hiep/>
# {'title': 'Nhật Ký Tu Tiên Của Gián Tinh', 'author': None, 'book_url': 'https://truyenfull.io/nhat-ky-tu-tien-cua-gian-tinh/', 'latest_chapter': 'https://truyenfull.io/nhat-ky-tu-tien-cua-gian-tinh/chuong-8/'}
# 2025-01-02 16:32:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://truyenfull.io/the-loai/tien-hiep/>
# {'title': 'Nữ Nhi Quốc - Vũ Sơn Nhất Định Bất Hoá', 'author': None, 'book_url': 'https://truyenfull.io/nu-nhi-quoc-vu-son-nhat-dinh-bat-hoa/', 'latest_chapter': 'https://truyenfull.io/nu-nhi-quoc-vu-son-nhat-dinh-bat-hoa/chuong-6/'}
# 2025-01-02 16:32:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://truyenfull.io/the-loai/tien-hiep/>
# {'title': 'Thần Võ Thiên Tôn - Thục Kỷ', 'author': None, 'book_url': 'https://truyenfull.io/than-vo-thien-ton-thuc-ky/', 'latest_chapter': 'https://truyenfull.io/than-vo-thien-ton-thuc-ky/chuong-165/'}
# 2025-01-02 16:32:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://truyenfull.io/the-loai/tien-hiep/>
# {'title': 'Ngạo Nghễ Trảm Thần - SS Hà Thần', 'author': None, 'book_url': 'https://truyenfull.io/ngao-nghe-tram-than-ss-ha-than/', 'latest_chapter': 'https://truyenfull.io/ngao-nghe-tram-than-ss-ha-than/chuong-89/'}
# 2025-01-02 16:32:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://truyenfull.io/the-loai/tien-hiep/>
# {'title': 'Thiên Đạo Hữu Khuyết - Bông Lan', 'author': None, 'book_url': 'https://truyenfull.io/thien-dao-huu-khuyet-bong-lan/', 'latest_chapter': 'https://truyenfull.io/thien-dao-huu-khuyet-bong-lan/chuong-266/'}
# 2025-01-02 16:32:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://truyenfull.io/the-loai/tien-hiep/>
# {'title': 'Bị Sói Con Cố Chấp Ngoạm Về Ổ', 'author': None, 'book_url': 'https://truyenfull.io/bi-soi-con-co-chap-ngoam-ve-o/', 'latest_chapter': 'https://truyenfull.io/bi-soi-con-co-chap-ngoam-ve-o/chuong-30/'}
# 2025-01-02 16:32:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://truyenfull.io/the-loai/tien-hiep/>
# {'title': 'Ta Không Làm Kiếm Chủ Đã Nhiều Năm', 'author': None, 'book_url': 'https://truyenfull.io/ta-khong-lam-kiem-chu-da-nhieu-nam/', 'latest_chapter': 'https://truyenfull.io/ta-khong-lam-kiem-chu-da-nhieu-nam/chuong-64/'}
# 2025-01-02 16:32:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://truyenfull.io/the-loai/tien-hiep/>
# {'title': 'Trăn Trăn Mỹ Nhân Tâm - Thập Tứ Lang', 'author': None, 'book_url': 'https://truyenfull.io/tran-tran-my-nhan-tam-thap-tu-lang/', 'latest_chapter': 'https://truyenfull.io/tran-tran-my-nhan-tam-thap-tu-lang/chuong-162/'}
# 2025-01-02 16:32:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://truyenfull.io/the-loai/tien-hiep/>
# {'title': 'Sư Tỷ, Ta Không Muốn Cố Gắng Nữa!', 'author': None, 'book_url': 'https://truyenfull.io/su-ty-ta-khong-muon-co-gang-nua/', 'latest_chapter': 'https://truyenfull.io/su-ty-ta-khong-muon-co-gang-nua/chuong-34/'}
# 2025-01-02 16:32:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://truyenfull.io/the-loai/tien-hiep/>
# {'title': 'Tiêu Dao Tứ Công Tử - Tu Quả', 'author': None, 'book_url': 'https://truyenfull.io/tieu-dao-tu-cong-tu-tu-qua/', 'latest_chapter': 'https://truyenfull.io/tieu-dao-tu-cong-tu-tu-qua/chuong-201/'}
# 2025-01-02 16:32:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://truyenfull.io/the-loai/tien-hiep/>
# {'title': 'Tất Cả Phản Diện Đều Hắc Hóa, Chỉ Có Sư Muội Là Hài Hước', 'author': None, 'book_url': 'https://truyenfull.io/tat-ca-phan-dien-deu-hac-hoa-chi-co-su-muoi-la-hai-huoc/', 'latest_chapter': 'https://truyenfull.io/tat-ca-phan-dien-deu-hac-hoa-chi-co-su-muoi-la-hai-huoc/chuong-99/'}
# 2025-01-02 16:32:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://truyenfull.io/the-loai/tien-hiep/>
# {'title': 'Ta Có Thể Sờ Cái Đuôi Của Ngươi Không?', 'author': None, 'book_url': 'https://truyenfull.io/ta-co-the-so-cai-duoi-cua-nguoi-khong/', 'latest_chapter': 'https://truyenfull.io/ta-co-the-so-cai-duoi-cua-nguoi-khong/chuong-51/'}
# 2025-01-02 16:32:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://truyenfull.io/the-loai/tien-hiep/>
# {'title': 'Ta Dựa Vào Y Thuật Tung Hoành Tu Tiên Giới', 'author': None, 'book_url': 'https://truyenfull.io/ta-dua-vao-y-thuat-tung-hoanh-tu-tien-gioi/', 'latest_chapter': 'https://truyenfull.io/ta-dua-vao-y-thuat-tung-hoanh-tu-tien-gioi/chuong-643/'}
# 2025-01-02 16:32:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://truyenfull.io/the-loai/tien-hiep/>
# {'title': 'Xuyên Qua Làm Nhân Vật Quần Chúng, Vô Tình Dạy Một Đám Đồ Đệ Thành Thánh Nhân', 'author': None, 'book_url': 'https://truyenfull.io/xuyen-qua-lam-nhan-vat-quan-chung-vo-tinh-day-mot-dam-do-de-thanh-thanh-nhan/', 'latest_chapter': 'https://truyenfull.io/xuyen-qua-lam-nhan-vat-quan-chung-vo-tinh-day-mot-dam-do-de-thanh-thanh-nhan/chuong-535/'}
# 2025-01-02 16:32:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://truyenfull.io/the-loai/tien-hiep/>
# {'title': 'Nhất Khí Triều Dương - Thân Vẫn Chỉ Tiêm', 'author': None, 'book_url': 'https://truyenfull.io/nhat-khi-trieu-duong-than-van-chi-tiem/', 'latest_chapter': 'https://truyenfull.io/nhat-khi-trieu-duong-than-van-chi-tiem/chuong-78/'}
# 2025-01-02 16:32:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://truyenfull.io/the-loai/tien-hiep/>
# {'title': 'Linh Khí Hồi Phục, Ta Bắt Đầu Tu Tiên Từ Việc Làm Ruộng', 'author': None, 'book_url': 'https://truyenfull.io/linh-khi-hoi-phuc-ta-bat-dau-tu-tien-tu-viec-lam-ruong/', 'latest_chapter': 'https://truyenfull.io/linh-khi-hoi-phuc-ta-bat-dau-tu-tien-tu-viec-lam-ruong/chuong-47/'}
# 2025-01-02 16:32:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://truyenfull.io/the-loai/tien-hiep/>
# {'title': None, 'author': None, 'book_url': None, 'latest_chapter': None}
# 2025-01-02 16:32:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://truyenfull.io/the-loai/tien-hiep/>
# {'title': None, 'author': None, 'book_url': None, 'latest_chapter': None}
# 2025-01-02 16:32:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://truyenfull.io/the-loai/tien-hiep/>
# {'title': None, 'author': None, 'book_url': None, 'latest_chapter': None}
# 2025-01-02 16:32:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://truyenfull.io/the-loai/tien-hiep/>
# {'title': None, 'author': None, 'book_url': None, 'latest_chapter': None}
# 2025-01-02 16:32:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://truyenfull.io/the-loai/tien-hiep/>
# {'title': None, 'author': None, 'book_url': None, 'latest_chapter': None}
# 2025-01-02 16:32:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://truyenfull.io/the-loai/tien-hiep/>
# {'title': None, 'author': None, 'book_url': None, 'latest_chapter': None}
# 2025-01-02 16:32:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://truyenfull.io/the-loai/tien-hiep/>
# {'title': None, 'author': None, 'book_url': None, 'latest_chapter': None}
# 2025-01-02 16:32:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://truyenfull.io/the-loai/tien-hiep/>
# {'title': None, 'author': None, 'book_url': None, 'latest_chapter': None}
# 2025-01-02 16:32:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://truyenfull.io/the-loai/tien-hiep/>
# {'title': None, 'author': None, 'book_url': None, 'latest_chapter': None}
# 2025-01-02 16:32:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://truyenfull.io/the-loai/tien-hiep/>
# {'title': None, 'author': None, 'book_url': None, 'latest_chapter': None}
# 2025-01-02 16:32:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://truyenfull.io/the-loai/tien-hiep/>
# {'title': None, 'author': None, 'book_url': None, 'latest_chapter': None}
# 2025-01-02 16:32:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://truyenfull.io/the-loai/tien-hiep/>
# {'title': None, 'author': None, 'book_url': None, 'latest_chapter': None}
# 2025-01-02 16:32:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://truyenfull.io/the-loai/tien-hiep/>
# {'title': None, 'author': None, 'book_url': None, 'latest_chapter': None}
# 2025-01-02 16:32:44 [scrapy.core.engine] INFO: Closing spider (finished)
# 2025-01-02 16:32:44 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 218,
#  'downloader/request_count': 1,
#  'downloader/request_method_count/GET': 1,
#  'downloader/response_bytes': 19720,
#  'downloader/response_count': 1,
#  'downloader/response_status_count/200': 1,
#  'elapsed_time_seconds': 0.290762,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2025, 1, 2, 9, 32, 44, 931177, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 90236,
#  'httpcompression/response_count': 1,
#  'item_scraped_count': 41,
#  'log_count/DEBUG': 43,
#  'log_count/INFO': 10,
#  'log_count/WARNING': 1,
#  'memusage/max': 111575040,
#  'memusage/startup': 111575040,
#  'response_received_count': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2025, 1, 2, 9, 32, 44, 640415, tzinfo=datetime.timezone.utc)}
# 2025-01-02 16:32:44 [scrapy.core.engine] INFO: Spider closed (finished)
